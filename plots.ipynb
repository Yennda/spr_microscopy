# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
# sys.path.append('C:/Users/jabuk/PycharmProjects')
# from textable.datalist import DataList
#
yellow='#ffb200'
red='#DD5544'
blue='#0284C0'

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes.grid(linestyle='--')
axes.set_title('Title')
axes.set_xlabel('x')
axes.set_ylabel('y')

x = np.arange(1,10,0.2)
y = x**2 

name='test_01'
axes.plot(x, y, color=yellow, linewidth=2, label='x')
axes.plot(x, x**3, color=blue, linewidth=2, label='y')
axes.legend(loc=2)
# fig.savefig('jupyter_plots/' + name + '.png', dpi=300)

# %%
print('x\ty\tcx\tcy\tC\tstd\tint\tmaxint\trelBg')
print('\t'.join([str(i) for i in range(9)]))
# Out:
# x	y	cx	cy	C	std	int	maxint	relBg
# 0	1	2	3	4	5	6	7	8

# %%
name=L3

# %%
L3=np.asarray([
    [34.094545454545454, 18.379090909090905, 3.186363636363636, 3.255454545454546, 2.418127936440907, 0.000603551213528096, 0.06728140125689043, 0.00395964725195072, 0.00048090205027750255],
    [39.26199999999999, 17.872999999999998, 3.5140000000000002, 4.13, 2.5234587418380934, 0.000622382776205118, 0.082632996861607, 0.004682088899196666, 0.0004982593440794644],
    [37.504, 17.287, 5.695, 5.063, 3.0876957261073037, 0.00031868572642317083, 0.05753483568323038, 0.0035908353981196164, 0.00025013675198465156],
    [44.24300000000001, 19.044999999999998, 5.154000000000001, 4.586, 3.0614517066765483, 0.000476665992581127, 0.10348283507394127, 0.004858791111393423, 0.0003762184864183701],
    [35.15999999999999, 15.236, 3.9760000000000004, 3.7, 2.440184386182553, 0.001040188319045581, 0.10291740659019781, 0.006926216982321602, 0.0008250533251707899],
    [28.421000000000003, 14.65, 4.496, 3.897, 2.7106570181055494, 0.000862927767730055, 0.0779530602595306, 0.005869596255496101, 0.0006892958491297124],
    [31.351, 13.478, 4.955, 4.627999999999999, 3.21849696924932, 0.0007510603096131045, 0.08248689659852916, 0.005986621766950868, 0.0005954145367145545],
    [32.523, 13.770999999999997, 6.288, 6.386, 3.938938998290631, 0.0002837877919341401, 0.04539560909471099, 0.0031560524987106512, 0.00022553444029099772],
    [36.918000000000006, 13.478, 4.946, 5.131000000000001, 2.994956704630082, 0.00047937984630470464, 0.05826497319518111, 0.004217586644414135, 0.000380621838746383],
    [35.16, 14.942999999999998, 3.7340000000000004, 3.325, 2.273544853181686, 0.000603114551906409, 0.05205199780268917, 0.004037712533653056, 0.0004797514220618292],
    [35.452999999999996, 13.184999999999999, 3.0940000000000003, 3.872, 2.1830593018873894, 0.0005909740448178097, 0.04305904903648354, 0.003798002790383737, 0.0004737838646179008],
    [36.331999999999994, 10.841, 3.8009999999999997, 4.586, 2.7581223122556233, 0.0004450036111095936, 0.03959601079015949, 0.00330989302325898, 0.0003539191120122291],
    [32.23, 10.840999999999998, 4.148000000000001, 5.081000000000001, 3.0411516565325347, 0.00027780898945158967, 0.02520365603928181, 0.002252013786066559, 0.00022018224411733938],
    [41.60600000000001, 14.65, 5.3340000000000005, 4.496, 2.944145975733213, 0.00040069331599826443, 0.06056326147475268, 0.0037112850363282637, 0.00031439793717655387],
    [33.82818181818182, 11.187272727272727, 5.5627272727272725, 6.244545454545454, 3.9724413792918267, 0.0005182687136232973, 0.07009640956309005, 0.0050573023747908915, 0.000409662756507255],
    [24.026, 8.496999999999996, 3.883, 4.686999999999999, 3.3165692480416906, 0.00039810113704639977, 0.02368235788268598, 0.0026797193546157015, 0.0003154404999329717],
    [27.021111111111114, 10.743333333333332, 3.763333333333333, 4.394444444444444, 2.8802578374461394, 0.00033953824309479084, 0.02563346218132982, 0.0022446398995843893, 0.000267569299499337],
    [28.974444444444444, 7.813333333333334, 4.421111111111111, 6.198888888888889, 3.6960807929988135, 0.00023210927789589709, 0.017143587118565545, 0.0018076866267318298, 0.0001851829868095453],
    [30.472, 8.497, 4.256, 5.278999999999999, 3.4771288054568936, 0.000311568575919674, 0.02510502608690356, 0.0022388178713782427, 0.000247555518266229],
    [30.179000000000002, 7.911, 2.9039999999999995, 3.7269999999999994, 2.2651389632657186, 0.0004111678875164151, 0.01707469672809313, 0.002319309305767249, 0.000329630346290777],
])

# %%
L3[:5, 6]
# Out:
# array([0.0672814 , 0.082633  , 0.05753484, 0.10348284, 0.10291741])

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes.grid(linestyle='--')
axes.set_title('Title')
axes.set_xlabel('x')
axes.set_ylabel('y')

x=[726, 728, 730, 732, 734]
y=list(L3[:5, 6])
y=[y[1]]+[y[0]]+y[2:]
y2=list(L3[:5, 7])
y2=[y2[1]]+[y2[0]]+y2[2:]
print(y)
name='test_01'
axes.plot(x, y, color=yellow, linewidth=2, label='intensity')
axes.plot(x, y2, color=blue, linewidth=2, label='max. intensity')
axes.legend(loc=2)
# fig.savefig('jupyter_plots/' + name + '.png', dpi=300)
# Out:
# [0.082632996861607, 0.06728140125689043, 0.05753483568323038, 0.10348283507394127, 0.10291740659019781]

# %%
bw=np.random.rand(16, 16)
red=np.diag(np.ones(16))
both=np.dstack( ( bw, red ) )
# print(both)

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
axes.imshow(bw, cmap='gray')
axes.imshow(red, cmap='gray', alpha=.7)

plt.show()
